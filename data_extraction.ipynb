# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import os

# %%
# !pip install syllables
# Out:
# Collecting syllables
#   Downloading syllables-1.0.9-py3-none-any.whl (15 kB)
# Collecting cmudict<2.0.0,>=1.0.11 (from syllables)
#   Downloading cmudict-1.0.16-py3-none-any.whl (939 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.4/939.4 kB 8.1 MB/s eta 0:00:00
# Collecting importlib-metadata<7.0,>=5.1 (from syllables)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.10/dist-packages (from cmudict<2.0.0,>=1.0.11->syllables) (6.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7.0,>=5.1->syllables) (3.17.0)
# Installing collected packages: importlib-metadata, cmudict, syllables
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
# Successfully installed cmudict-1.0.16 importlib-metadata-6.11.0 syllables-1.0.9

# %%
# !pip install textstat
# Out:
# Collecting textstat
#   Downloading textstat-0.7.3-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 2.3 MB/s eta 0:00:00
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.3 MB/s eta 0:00:00
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.14.0 textstat-0.7.3

# %%
import syllables
import textstat
import math

# %%
from nltk.corpus import wordnet

# %%
raw = pd.read_csv('https://docs.google.com/spreadsheets/d/1XJIkYI7439sZbXeiEWzM7NboYKYOaujW/export?format=csv')

# %%
raw.head()
# Out:
#             URL_ID                                                URL
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...

# %%
df = raw.head(100)

# %%
url = df['URL']

# %%
url
# Out:
# 0     https://insights.blackcoffer.com/rising-it-cit...
# 1     https://insights.blackcoffer.com/rising-it-cit...
# 2     https://insights.blackcoffer.com/internet-dema...
# 3     https://insights.blackcoffer.com/rise-of-cyber...
# 4     https://insights.blackcoffer.com/ott-platform-...
#                             ...
# 95    https://insights.blackcoffer.com/what-is-the-r...
# 96    https://insights.blackcoffer.com/impact-of-cov...
# 97    https://insights.blackcoffer.com/contribution-...
# 98    https://insights.blackcoffer.com/how-covid-19-...
# 99    https://insights.blackcoffer.com/how-will-covi...
# Name: URL, Length: 100, dtype: object

# %%
import requests

# %%
import requests
from bs4 import BeautifulSoup

def scraping_title(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    Title = soup.select_one('h1.entry-title, h1.tdb-title-text')

    if Title is not None:
        return Title.text.strip()
    else:
        return "Title not found"

# %%
scraping_title(url[86])
# Out:
# 'Impacts of COVID 19 on Streets Sides Food Stalls'

# %%
title_list = []
for a in url:
  title_list.append(scraping_title(a))
title_list
# Out:
# ['Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.',
#  'Rising IT Cities and Their Impact on the Economy, Environment, Infrastructure, and City Life in Future',
#  'Internet Demand’s Evolution, Communication Impact, and 2035’s Alternative Pathways',
#  'Rise of Cybercrime and its Effect in upcoming Future',
#  'OTT platform and its impact on the entertainment industry in Future.',
#  'The rise of the OTT platform and its impact on the entertainment industry by 2040.',
#  'Rise of Cyber Crime and its Effects',
#  'Rise of Internet Demand and Its Impact on Communications and Alternatives by the Year 2035',
#  'Rise of Cybercrime and its Effect by the Year 2040.',
#  'Rise of Cybercrime and its Effect by the Year 2040.',
#  'Rise of Internet Demand and its Impact on Communications and Alternatives by the Year 2035.',
#  'Rise of telemedicine and its Impact on Livelihood by 2040',
#  'Rise of e-health and its impact on humans by the year 2030',
#  'Rise of e-health and its impact on humans by the year 2030',
#  'Rise of telemedicine and its Impact on Livelihood by 2040',
#  'Rise of telemedicine and its Impact on Livelihood by 2040',
#  'Rise of Chatbots and its impact on customer support by the year 2040',
#  'Rise of e-health and its impact on humans by the year 2030',
#  'How does marketing influence businesses and consumers?',
#  'How advertisement increase your market value?',
#  'Negative effects of marketing on society',
#  'How advertisement/marketing affects business.',
#  'Rising IT cities will impact the economy, environment, infrastructure, and city life by the year 2035',
#  'Rise of OTT platform and its impact on entertainment industry by the year 2030',
#  'Rise of Electric Vehicles and its Impact on Livelihood by 2040',
#  'Rise of electric vehicle and its impact on livelihood by the year 2040.',
#  'Oil prices by the year 2040, and how it will impact the world economy.',
#  'An outlook of healthcare by the year 2040, and how it will impact human lives.',
#  'AI in healthcare to Improve Patient Outcomes',
#  'What if the Creation is Taking Over the Creator?',
#  'What Jobs Will Robots Take From Humans in The Future?',
#  'Will Machine Replace The Human in the Future of Work?',
#  'Will AI Replace Us or Work With Us?',
#  'Will machine replace the human in the future of work?',
#  'How humans and machines are evolving to work together?',
#  'Title not found',
#  'How machine learning will affect your business?',
#  'Deep learning impact on areas of e-learning?',
#  'How to protect future data and its privacy?',
#  'How Machines, AI, Automations, and Robo-human are Effective in Finance and Banking?',
#  'How Robo Human will Impact the Future?',
#  'How AI will change the World?',
#  'Future of Work: How AI Has Entered the Workplace',
#  'How machine learning used in finance and banking?',
#  'How AI will impact the future of work?',
#  'All you need to know about online marketing',
#  'Evolution of Advertising Industry',
#  'How Data Analytics can help your business respond to the impact of COVID-19?',
#  'Title not found',
#  'Environmental impact of the COVID-19 pandemic – Lesson for the Future',
#  'How Data Analytics and AI are used to halt the COVID-19 Pandemic?',
#  'What is the difference between Artificial Intelligence, Machine Learning, Statistics, and Data Mining?',
#  'How Python became the first choice for Data Science.',
#  'How Google fit measure heart and respiratory rates using a phone camera?',
#  'What is the future of mobile apps?',
#  'Impact of AI in health and medicine',
#  'What patients like and dislike about telemedicine?',
#  'How we forecast future technologies?',
#  'Can robots tackle late-life loneliness?',
#  'Embedding care robots into society and practice: Socio-technical considerations',
#  'Management challenges for future digitalization of healthcare services',
#  'Are we any closer to preventing a nuclear holocaust?',
#  'Will technology eliminate the need for animal testing in drug development?',
#  'Will we ever understand the nature of consciousness?',
#  'Will we ever colonize outer space?',
#  'What is the chance Homo sapiens will survive for the next 500 years?',
#  'Why does your business need a chatbot?',
#  'How you lead a project or a team without any technical expertise?',
#  'Can You Be Great Leader Without Technical Expertise',
#  'How does artificial intelligence affect the environment',
#  'How to Overcome Your Fear of Making Mistakes',
#  'Is Perfection the Greatest enemy of Productivity?',
#  'Global financial crisis 2008 causes/effects and its solution',
#  'Gender diversity and Equality in the tech industry',
#  'How to overcome your fear of making mistakes?',
#  'How Small Business can survive the Coronavirus Crisis',
#  'Impacts of COVID 19 on Food products',
#  'Impacts of COVID 19 on Vegetable Vendors',
#  'Impact of COVID-19 pandemic on Tourism & Aviation industries',
#  'Impact of COVID-19 pandemic on sports events around the world.',
#  'Changing landscape and emerging trends in the Indian IT/ITeS Industry.',
#  'Online gaming: Adolescent online gaming effects demotivated, depression, musculoskeletal, and psychosomatic symptoms.',
#  'Human Rights Outlook',
#  'How Voice search makes your business a successful business.',
#  'How the COVID-19 crisis is redefining jobs and services?',
#  'How to increase social media engagement for marketers?',
#  'Impacts of COVID 19 on Streets Sides Food Stalls',
#  'Coronavirus impact on energy markets',
#  'COVID-19 Impact on Hospitality Industry',
#  'Lessons from the past: Some key learnings relevant to the coronavirus crisis',
#  'Estimating the impact of COVID-19 on the world of work',
#  'Estimating the impact of COVID-19 on the world of work',
#  'Travel and Tourism Outlook',
#  'Gaming Disorder and Effects of Gaming on Health.',
#  'What is the repercussion of the environment due to the COVID-19 pandemic situation?',
#  'Due to the COVID-19 the repercussion of the environment',
#  'Impact of COVID-19 pandemic on office space and co-working industries.',
#  'Contribution of handicrafts (Visual Arts & Literature) in the Indian economy',
#  'How COVID-19 is impacting payment preferences?',
#  'How will COVID-19 affect the world of work?']

# %%
for i, title in enumerate(title_list):
  if title == "no title":
    print(i+9)

# %%
def scraping_text(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')
  Text = soup.find('div', class_ = 'td-post-content tagdiv-type')
  # print(Text)
  if Text:
    text = ""
    for data in Text:
      text += Text.get_text(strip = True)
  else:
    text = "no text"
  print(text)

# %%
scraping_text(url[75])
# Out:
# The word pandemic may be the most used word for the last decade, and we know why. The year 2020 comes with a lot of unprecedented threats to humans as well as to nature. While no business was left insulated from its effect, small businesses were one of the most affected, as they rely on day to day sales and keep the inventory minimum, based on the demand of customers and have a low margin to maneuver.In an article by HSBC’s Navigator, which described the preparedness and contingency plan for the future, Indian business rated high among its peers. The businesses in India have shown resilience to face adversity which can be attributed to varying degrees of adjustment and adaptability. The businesses, while able to adhere to government guidelines have managed to facilitate their customers efficiently and effectively. However, the impact on micro, small, and medium enterprises cannot be left unattended.The Indian subcontinent has an estimated₹ 633.88 lakhof MSME, out of which51.2%are in rural areas whichemploy 44.84%of the total employment provided by this Sector. The MSME sector with1170 lakhpeople constitutes 40% of the total workforce. As per the ministry of commerce MSME contribution inGross Domestic Product (GDP) and export are 37% and 43% respectively.With the huge contribution toward GDP as well as export, the impact on the national economy due to the shock in the MSME sector from the pandemic will be equally devastating. While different businesses face different types of obstacles, we have pointed out 8 of the most common issues faced by them.Low Working Capital-: Small Businesses usually have a low working capital ratio which means that they don’t have enough capital to finance their daily requirements. In these difficult times, this problem has gone to the next level as they will have obligations to pay but due to less or no revenue for a few months, there are high chances that they may not be able to meet them.Low Cash Cycle-: According to a survey done by economic times, they have found that small businesses usually run on a 27 days cash cycle and due to pandemic looming around they are not able to operate efficiently. More than half of the small businesses of the country have either exhausted their funds or are close to doing so. It is because of the unprecedented demand crash due to lockdown.Not Registered-: Many of the small businesses in India are not registered as they are just too small and this invisibility is both an advantage and disadvantage for them. Being out of the formal system, they don’t have to maintain proper books of accounts, pay the taxes and follow all the regulatory norms but the downside of this is that it is difficult for them to access government programs focused on them and make use of it.Difficult to get financial support-: It becomes a huge task for small businesses when it comes to getting loans. This is because they don’t have proper accounts and assets which they can keep as mortgage to get loans from banks. Due to this, they have to use a traditional method of lending which involves a high rate of interest and during these times it is also getting difficult to get loans from this area.Existential Crisis: –With the abrupt change in the business environment the businesses either have low production or they cease to exist. While low production will put a burden on the owner’s pocket but if they closed their business and start fresh, the cost of starting a new business post-crisis will be high and with limited creditworthiness which makes business difficult to regain their lost market share.Migration-: In the starting days of lockdown small businesses were not able to pay their workers which led to migration, as they moved back to their hometowns. This has led to a problem of the availability of a suitable workforce for these businesses as they are trying to get things back to normal.Absence of skills required-: As, hiring of new workers is done to get things to normal it is getting difficu ...

# %%
def scraping_data(url, i):
    response = requests.get(url)
    all_text = BeautifulSoup(response.text, 'html.parser')

    Title = all_text.select_one('h1.entry-title , h1.tdb-title-text')
    title = Title.get_text(strip=True) if Title else "No Title"

    Text = all_text.find('div', class_='td-post-content tagdiv-type')
    text = Text.get_text(strip=True) if Text else "No Text"

    folder_name = "Output_scraped_data"
    os.makedirs(folder_name, exist_ok=True)
    file_name = os.path.join(folder_name, f"blackassign{i}")

    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(f"Title: {title}\n")
        file.write(text)

# %%
for i, row in enumerate(url):
  scraping_data(row, i+ 1)

# %%
# import shutil

# # Specify the path to the folder you want to delete
# folder_path = '/content/Output_scraped_data'  # Replace with the actual path

# # Use shutil.rmtree to delete the folder and its contents
# shutil.rmtree(folder_path)

# # Optionally, check if the folder still exists
# if not os.path.exists(folder_path):
#     print(f"The folder {folder_path} has been successfully deleted.")
# else:
#     print(f"Failed to delete the folder {folder_path}.")

# %%
Columns = ['URL_ID','URL','POSITIVE SCORE','NEGATIVE SCORE','POLARITY SCORE','SUBJECTIVITY SCORE','AVG SENTENCE LENGTH','PERCENTAGE OF COMPLEX WORDS','FOG INDEX','AVG NUMER OF WORDS PER SENTENCE','COMPLEX WORD COUNT','WORD COUNT','WORD COUNT','SYLLABLE PER WORD','PERSONAL PRONOUNS','PERSONAL PRONOUNS','AVG WORD LENGHT']
df = pd.DataFrame(columns = Columns)

# %%
url_id = raw['URL_ID'].head(20)
df['URL_ID'] = url_id
df['URL'] = url
df
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# 5   blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# 6   blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# 7   blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# 8   blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# 9   blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
# 10  blackassign0011  https://insights.blackcoffer.com/rise-of-inter...
# 11  blackassign0012  https://insights.blackcoffer.com/rise-of-telem...
# 12  blackassign0013  https://insights.blackcoffer.com/rise-of-e-hea...
# 13  blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# 14  blackassign0015  https://insights.blackcoffer.com/rise-of-telem...
# 15  blackassign0016  https://insights.blackcoffer.com/rise-of-telem...
# 16  blackassign0017  https://insights.blackcoffer.com/rise-of-chatb...
# 17  blackassign0018  https://insights.blackcoffer.com/rise-of-e-hea...
# 18  blackassign0019  https://insights.blackcoffer.com/how-does-mark...
# 19  blackassign0020  https://insights.blackcoffer.com/how-advertise...
#
#    POSITIVE SCORE NEGATIVE SCORE POLARITY SCORE SUBJECTIVITY SCORE  \
# 0             NaN            NaN            NaN                NaN
# 1             NaN            NaN            NaN                NaN
# 2             NaN            NaN            NaN                NaN
# 3             NaN            NaN            NaN                NaN
# 4             NaN            NaN            NaN                NaN
# 5             NaN            NaN            NaN                NaN
# 6             NaN            NaN            NaN                NaN
# 7             NaN            NaN            NaN                NaN
# 8             NaN            NaN            NaN                NaN
# 9             NaN            NaN            NaN                NaN
# 10            NaN            NaN            NaN                NaN
# 11            NaN            NaN            NaN                NaN
# 12            NaN            NaN            NaN                NaN
# 13            NaN            NaN            NaN                NaN
# 14            NaN            NaN            NaN                NaN
# 15            NaN            NaN            NaN                NaN
# 16            NaN            NaN            NaN                NaN
# 17            NaN            NaN            NaN                NaN
# 18            NaN            NaN            NaN                NaN
# 19            NaN            NaN            NaN                NaN
#
#    AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS FOG INDEX  \
# 0                  NaN                         NaN       NaN
# 1                  NaN                         NaN       NaN
# 2                  NaN                         NaN       NaN
# 3                  NaN                         NaN       NaN
# 4                  NaN                         NaN       NaN
# 5                  NaN                         NaN       NaN
# 6                  NaN                         NaN       NaN
# 7                  NaN                         NaN       NaN
# 8                  NaN                         NaN       NaN
# 9                  NaN                         NaN       NaN
# 10                 NaN                         NaN       NaN
# 11                 NaN                         NaN       NaN
# 12                 NaN                         NaN       NaN
# 13                 NaN                         NaN       NaN
# 14                 NaN                         NaN       NaN
# 15                 NaN                         NaN       NaN
# 16                 NaN                         NaN       NaN
# 17                 NaN                         NaN       NaN
# 18                 NaN                         NaN       NaN
# 19                 NaN                         NaN       NaN
#
#    AVG NUMER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT WORD COUNT  \
# 0                              NaN                NaN        NaN        NaN
# 1                              NaN                NaN        NaN        NaN
# 2                              NaN                NaN        NaN        NaN
# 3                              NaN                NaN        NaN        NaN
# 4                              NaN                NaN        NaN        NaN
# 5                              NaN                NaN        NaN        NaN
# 6                              NaN                NaN        NaN        NaN
# 7                              NaN                NaN        NaN        NaN
# 8                              NaN                NaN        NaN        NaN
# 9                              NaN                NaN        NaN        NaN
# 10                             NaN                NaN        NaN        NaN
# 11                             NaN                NaN        NaN        NaN
# 12                             NaN                NaN        NaN        NaN
# 13                             NaN                NaN        NaN        NaN
# 14                             NaN                NaN        NaN        NaN
# 15                             NaN                NaN        NaN        NaN
# 16                             NaN                NaN        NaN        NaN
# 17                             NaN                NaN        NaN        NaN
# 18                             NaN                NaN        NaN        NaN
# 19                             NaN                NaN        NaN        NaN
#
#    SYLLABLE PER WORD PERSONAL PRONOUNS PERSONAL PRONOUNS AVG WORD LENGHT
# 0                NaN               NaN               NaN             NaN
# 1                NaN               NaN               NaN             NaN
# 2                NaN               NaN               NaN             NaN
# 3                NaN               NaN               NaN             NaN
# 4                NaN               NaN               NaN             NaN
# 5                NaN               NaN               NaN             NaN
# 6                NaN               NaN               NaN             NaN
# 7                NaN               NaN               NaN             NaN
# 8                NaN               NaN               NaN             NaN
# 9                NaN               NaN               NaN             NaN
# 10               NaN               NaN               NaN             NaN
# 11               NaN               NaN               NaN             NaN
# 12               NaN               NaN               NaN             NaN
# 13               NaN               NaN               NaN             NaN
# 14               NaN               NaN               NaN             NaN
# 15               NaN               NaN               NaN             NaN
# 16               NaN               NaN               NaN             NaN
# 17               NaN               NaN               NaN             NaN
# 18               NaN               NaN               NaN             NaN
# 19               NaN               NaN               NaN             NaN

# %%
with open('positive-words.txt', 'r') as file:
  positive_words_text = file.read()
with open('negative-words.txt','r',encoding = 'latin-1') as file:
  negative_words_text = file.read()
positive_words = positive_words_text.split()
negative_words = negative_words_text.split()
print(positive_words)
print(negative_words)
# Out:
# ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation', 'accolade', 'accolades', 'accommodative', 'accomodative', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', 'accurate', 'accurately', 'achievable', 'achievement', 'achievements', 'achievible', 'acumen', 'adaptable', 'adaptive', 'adequate', 'adjustable', 'admirable', 'admirably', 'admiration', 'admire', 'admirer', 'admiring', 'admiringly', 'adorable', 'adore', 'adored', 'adorer', 'adoring', 'adoringly', 'adroit', 'adroitly', 'adulate', 'adulation', 'adulatory', 'advanced', 'advantage', 'advantageous', 'advantageously', 'advantages', 'adventuresome', 'adventurous', 'advocate', 'advocated', 'advocates', 'affability', 'affable', 'affably', 'affectation', 'affection', 'affectionate', 'affinity', 'affirm', 'affirmation', 'affirmative', 'affluence', 'affluent', 'afford', 'affordable', 'affordably', 'afordable', 'agile', 'agilely', 'agility', 'agreeable', 'agreeableness', 'agreeably', 'all-around', 'alluring', 'alluringly', 'altruistic', 'altruistically', 'amaze', 'amazed', 'amazement', 'amazes', 'amazing', 'amazingly', 'ambitious', 'ambitiously', 'ameliorate', 'amenable', 'amenity', 'amiability', 'amiabily', 'amiable', 'amicability', 'amicable', 'amicably', 'amity', 'ample', 'amply', 'amuse', 'amusing', 'amusingly', 'angel', 'angelic', 'apotheosis', 'appeal', 'appealing', 'applaud', 'appreciable', 'appreciate', 'appreciated', 'appreciates', 'appreciative', 'appreciatively', 'appropriate', 'approval', 'approve', 'ardent', 'ardently', 'ardor', 'articulate', 'aspiration', 'aspirations', 'aspire', 'assurance', 'assurances', 'assure', 'assuredly', 'assuring', 'astonish', 'astonished', 'astonishing', 'astonishingly', 'astonishment', 'astound', 'astounded', 'astounding', 'astoundingly', 'astutely', 'attentive', 'attraction', 'attractive', 'attractively', 'attune', 'audible', 'audibly', 'auspicious', 'authentic', 'authoritative', 'autonomous', 'available', 'aver', 'avid', 'avidly', 'award', 'awarded', 'awards', 'awe', 'awed', 'awesome', 'awesomely', 'awesomeness', 'awestruck', 'awsome', 'backbone', 'balanced', 'bargain', 'beauteous', 'beautiful', 'beautifullly', 'beautifully', 'beautify', 'beauty', 'beckon', 'beckoned', 'beckoning', 'beckons', 'believable', 'believeable', 'beloved', 'benefactor', 'beneficent', 'beneficial', 'beneficially', 'beneficiary', 'benefit', 'benefits', 'benevolence', 'benevolent', 'benifits', 'best', 'best-known', 'best-performing', 'best-selling', 'better', 'better-known', 'better-than-expected', 'beutifully', 'blameless', 'bless', 'blessing', 'bliss', 'blissful', 'blissfully', 'blithe', 'blockbuster', 'bloom', 'blossom', 'bolster', 'bonny', 'bonus', 'bonuses', 'boom', 'booming', 'boost', 'boundless', 'bountiful', 'brainiest', 'brainy', 'brand-new', 'brave', 'bravery', 'bravo', 'breakthrough', 'breakthroughs', 'breathlessness', 'breathtaking', 'breathtakingly', 'breeze', 'bright', 'brighten', 'brighter', 'brightest', 'brilliance', 'brilliances', 'brilliant', 'brilliantly', 'brisk', 'brotherly', 'bullish', 'buoyant', 'cajole', 'calm', 'calming', 'calmness', 'capability', 'capable', 'capably', 'captivate', 'captivating', 'carefree', 'cashback', 'cashbacks', 'catchy', 'celebrate', 'celebrated', 'celebration', 'celebratory', 'champ', 'champion', 'charisma', 'charismatic', 'charitable', 'charm', 'charming', 'charmingly', 'chaste', 'cheaper', 'cheapest', 'cheer', 'cheerful', 'cheery', 'cherish', 'cherished', 'cherub', 'chic', 'chivalrous', 'chivalry', 'civility', 'civilize', 'clarity', 'classic', 'classy', 'clean', 'cleaner', 'cleanest', 'cleanliness', 'cleanly', 'clear', 'clear-cut', 'cleared', 'clearer', 'clearly', 'clears', 'clever', 'cleverly', 'cohere', 'coherence', 'coherent', 'cohesive', 'colorful', 'comely', 'comfort', 'comfortable', 'comfortably', 'comforting', 'comfy', 'commend', 'commendable', 'commendably', 'commitment', 'commodious', 'compact', 'compactly', 'compassion', 'co ...
# ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted', 'aborts', 'abrade', 'abrasive', 'abrupt', 'abruptly', 'abscond', 'absence', 'absent-minded', 'absentee', 'absurd', 'absurdity', 'absurdly', 'absurdness', 'abuse', 'abused', 'abuses', 'abusive', 'abysmal', 'abysmally', 'abyss', 'accidental', 'accost', 'accursed', 'accusation', 'accusations', 'accuse', 'accuses', 'accusing', 'accusingly', 'acerbate', 'acerbic', 'acerbically', 'ache', 'ached', 'aches', 'achey', 'aching', 'acrid', 'acridly', 'acridness', 'acrimonious', 'acrimoniously', 'acrimony', 'adamant', 'adamantly', 'addict', 'addicted', 'addicting', 'addicts', 'admonish', 'admonisher', 'admonishingly', 'admonishment', 'admonition', 'adulterate', 'adulterated', 'adulteration', 'adulterier', 'adversarial', 'adversary', 'adverse', 'adversity', 'afflict', 'affliction', 'afflictive', 'affront', 'afraid', 'aggravate', 'aggravating', 'aggravation', 'aggression', 'aggressive', 'aggressiveness', 'aggressor', 'aggrieve', 'aggrieved', 'aggrivation', 'aghast', 'agonies', 'agonize', 'agonizing', 'agonizingly', 'agony', 'aground', 'ail', 'ailing', 'ailment', 'aimless', 'alarm', 'alarmed', 'alarming', 'alarmingly', 'alienate', 'alienated', 'alienation', 'allegation', 'allegations', 'allege', 'allergic', 'allergies', 'allergy', 'aloof', 'altercation', 'ambiguity', 'ambiguous', 'ambivalence', 'ambivalent', 'ambush', 'amiss', 'amputate', 'anarchism', 'anarchist', 'anarchistic', 'anarchy', 'anemic', 'anger', 'angrily', 'angriness', 'angry', 'anguish', 'animosity', 'annihilate', 'annihilation', 'annoy', 'annoyance', 'annoyances', 'annoyed', 'annoying', 'annoyingly', 'annoys', 'anomalous', 'anomaly', 'antagonism', 'antagonist', 'antagonistic', 'antagonize', 'anti-', 'anti-american', 'anti-israeli', 'anti-occupation', 'anti-proliferation', 'anti-semites', 'anti-social', 'anti-us', 'anti-white', 'antipathy', 'antiquated', 'antithetical', 'anxieties', 'anxiety', 'anxious', 'anxiously', 'anxiousness', 'apathetic', 'apathetically', 'apathy', 'apocalypse', 'apocalyptic', 'apologist', 'apologists', 'appal', 'appall', 'appalled', 'appalling', 'appallingly', 'apprehension', 'apprehensions', 'apprehensive', 'apprehensively', 'arbitrary', 'arcane', 'archaic', 'arduous', 'arduously', 'argumentative', 'arrogance', 'arrogant', 'arrogantly', 'ashamed', 'asinine', 'asininely', 'asinininity', 'askance', 'asperse', 'aspersion', 'aspersions', 'assail', 'assassin', 'assassinate', 'assault', 'assult', 'astray', 'asunder', 'atrocious', 'atrocities', 'atrocity', 'atrophy', 'attack', 'attacks', 'audacious', 'audaciously', 'audaciousness', 'audacity', 'audiciously', 'austere', 'authoritarian', 'autocrat', 'autocratic', 'avalanche', 'avarice', 'avaricious', 'avariciously', 'avenge', 'averse', 'aversion', 'aweful', 'awful', 'awfully', 'awfulness', 'awkward', 'awkwardness', 'ax', 'babble', 'back-logged', 'back-wood', 'back-woods', 'backache', 'backaches', 'backaching', 'backbite', 'backbiting', 'backward', 'backwardness', 'backwood', 'backwoods', 'bad', 'badly', 'baffle', 'baffled', 'bafflement', 'baffling', 'bait', 'balk', 'banal', 'banalize', 'bane', 'banish', 'banishment', 'bankrupt', 'barbarian', 'barbaric', 'barbarically', 'barbarity', 'barbarous', 'barbarously', 'barren', 'baseless', 'bash', 'bashed', 'bashful', 'bashing', 'bastard', 'bastards', 'battered', 'battering', 'batty', 'bearish', 'beastly', 'bedlam', 'bedlamite', 'befoul', 'beg', 'beggar', 'beggarly', 'begging', 'beguile', 'belabor', 'belated', 'beleaguer', 'belie', 'belittle', 'belittled', 'belittling', 'bellicose', 'belligerence', 'belligerent', 'belligerently', 'bemoan', 'bemoaning', 'bemused', 'bent', 'berate', 'bereave', 'bereavement', 'bereft', 'berserk', 'beseech', 'beset', 'besiege', 'besmirch', 'bestial', 'betray', 'betrayal', 'betrayals', 'betrayer', 'betraying', 'betrays', 'bewail', 'beware', 'bewilder', 'bewildered', 'bewildering', 'bewilderingly', 'bewilderment', 'bewitch',  ...

# %%
def calculate_scores(text):
  positive_score = sum(word in positive_words for word in text)
  negative_score = sum(word in negative_words for word in text)
  polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
  return positive_score, negative_score, polarity_score

# %%
score_dataframe = pd.DataFrame(columns = ['file','positive score','negative score', 'polarity score','total word count', 'total sentence count'])
score_dataframe
# Out:
# Empty DataFrame
# Columns: [file, positive score, negative score, polarity score, total word count, total sentence count]
# Index: []

# %%
import os
import pandas as pd
folder_path = '/content/Output_scraped_data'
for file in os.listdir(folder_path):
  file_path = os.path.join(folder_path,file)
  file_part = os.path.splitext(file)[0]
  with open(file_path,'r') as raw_data:
    text = raw_data.read()
  sentences = sent_tokenize(text)
  number_of_sentences = len(sentences)
  text = text.split()
  word_count = len(text)
  positive_score, negative_score, polarity_score = calculate_scores(text)
  score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# Out:
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)
# <ipython-input-71-39fd5476a8d2>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_dataframe = score_dataframe.append({'file':file_part,'positive score':positive_score,'negative score':negative_score,'polarity score':polarity_score,'total word count':word_count,'total sentence count':number_of_sentences},ignore_index = True)

# %%
score_dataframe
# Out:
#               file positive score negative score  polarity score  \
# 0    blackassign20              0              0        0.000000
# 1    blackassign95              9             18       -0.333333
# 2    blackassign29              0              0        0.000000
# 3     blackassign3             35             19        0.296296
# 4    blackassign85             37             30        0.104478
# ..             ...            ...            ...             ...
# 595  blackassign64             28             36       -0.125000
# 596  blackassign22             13              8        0.238095
# 597  blackassign52             62             24        0.441860
# 598  blackassign41             28             20        0.166667
# 599  blackassign31             64             29        0.376344
#
#     total word count total sentence count
# 0                  9                    2
# 1                599                   18
# 2                 10                    1
# 3               1058                   46
# 4               1813                  104
# ..               ...                  ...
# 595             1697                   50
# 596              420                   23
# 597             1911                   86
# 598             1218                   65
# 599             1684                   66
#
# [600 rows x 6 columns]

# %%
score_dataframe.drop_duplicates()
# Out:
#              file positive score negative score  polarity score  \
# 0   blackassign20              0              0        0.000000
# 1   blackassign95              9             18       -0.333333
# 2   blackassign29              0              0        0.000000
# 3    blackassign3             35             19        0.296296
# 4   blackassign85             37             30        0.104478
# ..            ...            ...            ...             ...
# 95  blackassign64             28             36       -0.125000
# 96  blackassign22             13              8        0.238095
# 97  blackassign52             62             24        0.441860
# 98  blackassign41             28             20        0.166667
# 99  blackassign31             64             29        0.376344
#
#    total word count total sentence count
# 0                 9                    2
# 1               599                   18
# 2                10                    1
# 3              1058                   46
# 4              1813                  104
# ..              ...                  ...
# 95             1697                   50
# 96              420                   23
# 97             1911                   86
# 98             1218                   65
# 99             1684                   66
#
# [100 rows x 6 columns]

# %%
score_dataframe.sort_values(by = 'file', ascending = True)
# Out:
#               file positive score negative score  polarity score  \
# 166   blackassign1             41              5        0.782609
# 66    blackassign1             41              5        0.782609
# 366   blackassign1             41              5        0.782609
# 466   blackassign1             41              5        0.782609
# 266   blackassign1             41              5        0.782609
# ..             ...            ...            ...             ...
# 486  blackassign99              0              0        0.000000
# 186  blackassign99              0              0        0.000000
# 386  blackassign99              0              0        0.000000
# 586  blackassign99              0              0        0.000000
# 86   blackassign99              0              0        0.000000
#
#     total word count total sentence count
# 166             1197                   60
# 66              1197                   60
# 366             1197                   60
# 466             1197                   60
# 266             1197                   60
# ..               ...                  ...
# 486                9                    2
# 186                9                    2
# 386                9                    2
# 586                9                    2
# 86                 9                    2
#
# [600 rows x 6 columns]

# %%
def natural_sort_key(file_name):
    parts = re.split(r'(\d+)', file_name)
    return [int(part) if part.isdigit() else part.lower() for part in parts]

# %%
score_dataframe = score_dataframe.sort_values(by='file', key=lambda x: x.map(natural_sort_key))

# %%
score_dataframe.head(100)
# Out:
#               file positive score negative score  polarity score  \
# 466   blackassign1             41              5        0.782609
# 66    blackassign1             41              5        0.782609
# 266   blackassign1             41              5        0.782609
# 166   blackassign1             41              5        0.782609
# 566   blackassign1             41              5        0.782609
# ..             ...            ...            ...             ...
# 483  blackassign16             39             24        0.238095
# 115  blackassign17             47             10        0.649123
# 15   blackassign17             47             10        0.649123
# 415  blackassign17             47             10        0.649123
# 215  blackassign17             47             10        0.649123
#
#     total word count total sentence count
# 466             1197                   60
# 66              1197                   60
# 266             1197                   60
# 166             1197                   60
# 566             1197                   60
# ..               ...                  ...
# 483             1218                   45
# 115             1145                   44
# 15              1145                   44
# 415             1145                   44
# 215             1145                   44
#
# [100 rows x 6 columns]

# %%
df['POSITIVE SCORE'],df['NEGATIVE SCORE'], df['POLARITY SCORE'] = score_dataframe['positive score'], score_dataframe['negative score'], score_dataframe['polarity score']

# %%
df
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# 5   blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# 6   blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# 7   blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# 8   blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# 9   blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
# 10  blackassign0011  https://insights.blackcoffer.com/rise-of-inter...
# 11  blackassign0012  https://insights.blackcoffer.com/rise-of-telem...
# 12  blackassign0013  https://insights.blackcoffer.com/rise-of-e-hea...
# 13  blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# 14  blackassign0015  https://insights.blackcoffer.com/rise-of-telem...
# 15  blackassign0016  https://insights.blackcoffer.com/rise-of-telem...
# 16  blackassign0017  https://insights.blackcoffer.com/rise-of-chatb...
# 17  blackassign0018  https://insights.blackcoffer.com/rise-of-e-hea...
# 18  blackassign0019  https://insights.blackcoffer.com/how-does-mark...
# 19  blackassign0020  https://insights.blackcoffer.com/how-advertise...
#
#    POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0               0              0        0.000000                NaN
# 1               9             18       -0.333333                NaN
# 2               0              0        0.000000                NaN
# 3              35             19        0.296296                NaN
# 4              37             30        0.104478                NaN
# 5              16              6        0.454545                NaN
# 6              31             19        0.240000                NaN
# 7              32             23        0.163636                NaN
# 8              32             58       -0.288889                NaN
# 9              69             19        0.568182                NaN
# 10              5              3        0.250000                NaN
# 11              0              0        0.000000                NaN
# 12             13             36       -0.469388                NaN
# 13             28              7        0.600000                NaN
# 14             45             14        0.525424                NaN
# 15             47             10        0.649123                NaN
# 16              8              2        0.600000                NaN
# 17             34              9        0.581395                NaN
# 18             37             19        0.321429                NaN
# 19             54             15        0.565217                NaN
#
#    AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS FOG INDEX  \
# 0                  NaN                         NaN       NaN
# 1                  NaN                         NaN       NaN
# 2                  NaN                         NaN       NaN
# 3                  NaN                         NaN       NaN
# 4                  NaN                         NaN       NaN
# 5                  NaN                         NaN       NaN
# 6                  NaN                         NaN       NaN
# 7                  NaN                         NaN       NaN
# 8                  NaN                         NaN       NaN
# 9                  NaN                         NaN       NaN
# 10                 NaN                         NaN       NaN
# 11                 NaN                         NaN       NaN
# 12                 NaN                         NaN       NaN
# 13                 NaN                         NaN       NaN
# 14                 NaN                         NaN       NaN
# 15                 NaN                         NaN       NaN
# 16                 NaN                         NaN       NaN
# 17                 NaN                         NaN       NaN
# 18                 NaN                         NaN       NaN
# 19                 NaN                         NaN       NaN
#
#    AVG NUMER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT WORD COUNT  \
# 0                              NaN                NaN        NaN        NaN
# 1                              NaN                NaN        NaN        NaN
# 2                              NaN                NaN        NaN        NaN
# 3                              NaN                NaN        NaN        NaN
# 4                              NaN                NaN        NaN        NaN
# 5                              NaN                NaN        NaN        NaN
# 6                              NaN                NaN        NaN        NaN
# 7                              NaN                NaN        NaN        NaN
# 8                              NaN                NaN        NaN        NaN
# 9                              NaN                NaN        NaN        NaN
# 10                             NaN                NaN        NaN        NaN
# 11                             NaN                NaN        NaN        NaN
# 12                             NaN                NaN        NaN        NaN
# 13                             NaN                NaN        NaN        NaN
# 14                             NaN                NaN        NaN        NaN
# 15                             NaN                NaN        NaN        NaN
# 16                             NaN                NaN        NaN        NaN
# 17                             NaN                NaN        NaN        NaN
# 18                             NaN                NaN        NaN        NaN
# 19                             NaN                NaN        NaN        NaN
#
#    SYLLABLE PER WORD PERSONAL PRONOUNS PERSONAL PRONOUNS AVG WORD LENGHT
# 0                NaN               NaN               NaN             NaN
# 1                NaN               NaN               NaN             NaN
# 2                NaN               NaN               NaN             NaN
# 3                NaN               NaN               NaN             NaN
# 4                NaN               NaN               NaN             NaN
# 5                NaN               NaN               NaN             NaN
# 6                NaN               NaN               NaN             NaN
# 7                NaN               NaN               NaN             NaN
# 8                NaN               NaN               NaN             NaN
# 9                NaN               NaN               NaN             NaN
# 10               NaN               NaN               NaN             NaN
# 11               NaN               NaN               NaN             NaN
# 12               NaN               NaN               NaN             NaN
# 13               NaN               NaN               NaN             NaN
# 14               NaN               NaN               NaN             NaN
# 15               NaN               NaN               NaN             NaN
# 16               NaN               NaN               NaN             NaN
# 17               NaN               NaN               NaN             NaN
# 18               NaN               NaN               NaN             NaN
# 19               NaN               NaN               NaN             NaN

# %%
df.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#   POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0              0              0        0.000000                NaN
# 1              9             18       -0.333333                NaN
# 2              0              0        0.000000                NaN
# 3             35             19        0.296296                NaN
# 4             37             30        0.104478                NaN
#
#   AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS FOG INDEX  \
# 0                 NaN                         NaN       NaN
# 1                 NaN                         NaN       NaN
# 2                 NaN                         NaN       NaN
# 3                 NaN                         NaN       NaN
# 4                 NaN                         NaN       NaN
#
#   AVG NUMER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT WORD COUNT  \
# 0                             NaN                NaN        NaN        NaN
# 1                             NaN                NaN        NaN        NaN
# 2                             NaN                NaN        NaN        NaN
# 3                             NaN                NaN        NaN        NaN
# 4                             NaN                NaN        NaN        NaN
#
#   SYLLABLE PER WORD PERSONAL PRONOUNS PERSONAL PRONOUNS AVG WORD LENGHT
# 0               NaN               NaN               NaN             NaN
# 1               NaN               NaN               NaN             NaN
# 2               NaN               NaN               NaN             NaN
# 3               NaN               NaN               NaN             NaN
# 4               NaN               NaN               NaN             NaN

# %%
sentence_countdf = pd.DataFrame(columns = ['file', 'sentence count'])
sentence_countdf
# Out:
# Empty DataFrame
# Columns: [file, sentence count]
# Index: []

# %%
def sentence_count(file_path):
  with open(file_path, 'r') as files:
    texts = files.read()
  sentences = sent_tokenize(texts)
  number_of_sentences = len(sentences)
  return number_of_sentences

# %%
for file in os.listdir(folder_path):
  filepath = os.path.join(folder_path, file)
  filepart = os.path.splitext(file)[0]
  sentence_number = sentence_count(filepath)
  sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# Out:
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)
# <ipython-input-85-0f89b05ca212>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentence_countdf = sentence_countdf.append({'file':filepart, 'sentence count': sentence_number},ignore_index = True)

# %%
sentence_countdf = sentence_countdf.reset_index(drop = True)

# %%
sentence_countdf
# Out:
#               file sentence count
# 0    blackassign20              2
# 1    blackassign95             18
# 2    blackassign29              1
# 3     blackassign3             46
# 4    blackassign85            104
# ..             ...            ...
# 195  blackassign64             50
# 196  blackassign22             23
# 197  blackassign52             86
# 198  blackassign41             65
# 199  blackassign31             66
#
# [200 rows x 2 columns]

# %%
sentence_countdf.head(20)
# Out:
#              file sentence count
# 0   blackassign20              2
# 1   blackassign95             18
# 2   blackassign29              1
# 3    blackassign3             46
# 4   blackassign85            104
# 5   blackassign57             23
# 6   blackassign27             45
# 7   blackassign28             28
# 8    blackassign4             38
# 9   blackassign12             56
# 10  blackassign48              2
# 11  blackassign83              1
# 12  blackassign89             32
# 13   blackassign8             36
# 14  blackassign86             68
# 15  blackassign17             44
# 16  blackassign60              6
# 17  blackassign37             30
# 18  blackassign66             70
# 19  blackassign32             76

# %%
sentence_countdf['subejctivity_score'] = None
sentence_countdf
# Out:
#               file sentence count subejctivity_score
# 0    blackassign20              2               None
# 1    blackassign95             18               None
# 2    blackassign29              1               None
# 3     blackassign3             46               None
# 4    blackassign85            104               None
# ..             ...            ...                ...
# 195  blackassign64             50               None
# 196  blackassign22             23               None
# 197  blackassign52             86               None
# 198  blackassign41             65               None
# 199  blackassign31             66               None
#
# [200 rows x 3 columns]

# %%
df.head(10)
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# 5  blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# 6  blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# 7  blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# 8  blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# 9  blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
#
#   POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0              0              0        0.000000                NaN
# 1              9             18       -0.333333                NaN
# 2              0              0        0.000000                NaN
# 3             35             19        0.296296                NaN
# 4             37             30        0.104478                NaN
# 5             16              6        0.454545                NaN
# 6             31             19        0.240000                NaN
# 7             32             23        0.163636                NaN
# 8             32             58       -0.288889                NaN
# 9             69             19        0.568182                NaN
#
#   AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS FOG INDEX  \
# 0                 NaN                         NaN       NaN
# 1                 NaN                         NaN       NaN
# 2                 NaN                         NaN       NaN
# 3                 NaN                         NaN       NaN
# 4                 NaN                         NaN       NaN
# 5                 NaN                         NaN       NaN
# 6                 NaN                         NaN       NaN
# 7                 NaN                         NaN       NaN
# 8                 NaN                         NaN       NaN
# 9                 NaN                         NaN       NaN
#
#   AVG NUMER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT WORD COUNT  \
# 0                             NaN                NaN        NaN        NaN
# 1                             NaN                NaN        NaN        NaN
# 2                             NaN                NaN        NaN        NaN
# 3                             NaN                NaN        NaN        NaN
# 4                             NaN                NaN        NaN        NaN
# 5                             NaN                NaN        NaN        NaN
# 6                             NaN                NaN        NaN        NaN
# 7                             NaN                NaN        NaN        NaN
# 8                             NaN                NaN        NaN        NaN
# 9                             NaN                NaN        NaN        NaN
#
#   SYLLABLE PER WORD PERSONAL PRONOUNS PERSONAL PRONOUNS AVG WORD LENGHT
# 0               NaN               NaN               NaN             NaN
# 1               NaN               NaN               NaN             NaN
# 2               NaN               NaN               NaN             NaN
# 3               NaN               NaN               NaN             NaN
# 4               NaN               NaN               NaN             NaN
# 5               NaN               NaN               NaN             NaN
# 6               NaN               NaN               NaN             NaN
# 7               NaN               NaN               NaN             NaN
# 8               NaN               NaN               NaN             NaN
# 9               NaN               NaN               NaN             NaN

# %%
score_dataframe['total sentence count'] = sentence_countdf['sentence count']

# %%
score_dataframe = score_dataframe.drop_duplicates(subset = ['file'],keep = 'first')
score_dataframe = score_dataframe.reset_index(drop = True)

# %%
score_dataframe['total sentence count'] = sentence_countdf['sentence count']

# %%
score_dataframe['subjectivity score'] = (score_dataframe['positive score'] + score_dataframe['negative score'])/ (score_dataframe['total word count'] + 0.000001)
score_dataframe['average sentence lenght'] = score_dataframe['total word count']/score_dataframe['total sentence count']
score_dataframe['average sentence lenght'] = score_dataframe['average sentence lenght'].astype(int)

# %%
score_dataframe.head(10)
# Out:
#             file positive score negative score  polarity score  \
# 0   blackassign1             41              5        0.782609
# 1   blackassign2             54             22        0.421053
# 2   blackassign3             35             19        0.296296
# 3   blackassign4             32             58       -0.288889
# 4   blackassign5             18              7        0.440000
# 5   blackassign6             71             21        0.543478
# 6   blackassign7             29             51       -0.275000
# 7   blackassign8             28              7        0.600000
# 8   blackassign9             33             36       -0.043478
# 9  blackassign10            129            133       -0.015267
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
# 5             1792                   23           0.051339
# 6             1274                   45           0.062794
# 7              757                   28           0.046235
# 8              936                   38           0.073718
# 9             3581                   56           0.073164
#
#    average sentence lenght
# 0                      598
# 1                       80
# 2                     1058
# 3                       22
# 4                        6
# 5                       77
# 6                       28
# 7                       27
# 8                       24
# 9                       63

# %%
with open('/content/Output_scraped_data/blackassign6','r') as file:
  text = file.read()

syllable_count =  textstat.syllable_count(text)
print(syllable_count)
# Out:
# 3423

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
tempdf = pd.DataFrame(columns = ['file','complex word count'])
tempdf
# Out:
# Empty DataFrame
# Columns: [file, complex word count]
# Index: []

# %%
def is_complex(word):
    synsets = wordnet.synsets(word)
    return len(synsets) > 0

def count_complex_words(text):
    words = nltk.word_tokenize(text)
    complex_words_count = sum(1 for word in words if is_complex(word))
    return complex_words_count

folder = "/content/Output_scraped_data/"

for file in os.listdir(folder):
  file_path = os.path.join(folder,file)
  file_part = os.path.splitext(file)[0]
  with open(file_path, 'r', encoding='utf-8') as file_content:
    text = file_content.read()
  complex_words_count = count_complex_words(text)
  tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
  print("Count of complex words:", complex_words_count)
# Out:
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 7
# Count of complex words: 429
# Count of complex words: 9
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 747
# Count of complex words: 1246
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 272
# Count of complex words: 955
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 771
# Count of complex words: 768
# Count of complex words: 1123
# Count of complex words: 202
# Count of complex words: 6
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 673
# Count of complex words: 548
# Count of complex words: 1252
# Count of complex words: 789
# Count of complex words: 129
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 521
# Count of complex words: 1030
# Count of complex words: 1173
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 781
# Count of complex words: 815
# Count of complex words: 1310
# Count of complex words: 857
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 1151
# Count of complex words: 1150
# Count of complex words: 765
# Count of complex words: 557
# Count of complex words: 736
# Count of complex words: 127
# Count of complex words: 9
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 988
# Count of complex words: 420
# Count of complex words: 731
# Count of complex words: 503
# Count of complex words: 650
# Count of complex words: 7
# Count of complex words: 783
# Count of complex words: 5
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 970
# Count of complex words: 1237
# Count of complex words: 745
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 798
# Count of complex words: 484
# Count of complex words: 592
# Count of complex words: 1011
# Count of complex words: 5
# Count of complex words: 120
# Count of complex words: 1427
# Count of complex words: 467
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 735
# Count of complex words: 382
# Count of complex words: 10
# Count of complex words: 10
# Count of complex words: 1095
# Count of complex words: 729
# Count of complex words: 544
# Count of complex words: 1092
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 1126
# Count of complex words: 943
# Count of complex words: 587
# Count of complex words: 1549
# Count of complex words: 653
# Count of complex words: 672
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 516
# Count of complex words: 918
# Count of complex words: 884
# Count of complex words: 1179
# Count of complex words: 8
# Count of complex words: 1017
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 705
# Count of complex words: 739
# Count of complex words: 1038
# Count of complex words: 847
# Count of complex words: 792
# Count of complex words: 856
# Count of complex words: 806
# Count of complex words: 800
# Count of complex words: 1201
# Count of complex words: 384
# Count of complex words: 383
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 974
# Count of complex words: 1171
# Count of complex words: 847
# Count of complex words: 1046
# Count of complex words: 328
# Count of complex words: 7
# Count of complex words: 266
# Count of complex words: 397
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 2415
# Count of complex words: 2480
# Count of complex words: 1242
# Count of complex words: 844
# Count of complex words: 279
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)
# Count of complex words: 1261
# Count of complex words: 1227
# Count of complex words: 297
# Count of complex words: 1345
# Count of complex words: 905
# Count of complex words: 1259
# <ipython-input-99-da9763777f24>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempdf = tempdf.append({'file':file_part, 'complex word count': complex_words_count},ignore_index = True)

# %%
tempdf.head(30)
# Out:
#              file complex word count
# 0   blackassign20                  7
# 1   blackassign95                429
# 2   blackassign29                  9
# 3    blackassign3                747
# 4   blackassign85               1246
# 5   blackassign57                272
# 6   blackassign27                955
# 7   blackassign28                771
# 8    blackassign4                768
# 9   blackassign12               1123
# 10  blackassign48                202
# 11  blackassign83                  6
# 12  blackassign89                673
# 13   blackassign8                548
# 14  blackassign86               1252
# 15  blackassign17                789
# 16  blackassign60                129
# 17  blackassign37                521
# 18  blackassign66               1030
# 19  blackassign32               1173
# 20  blackassign21                781
# 21  blackassign94                815
# 22  blackassign45               1310
# 23  blackassign78                857
# 24  blackassign70               1151
# 25  blackassign42               1150
# 26  blackassign63                765
# 27  blackassign35                557
# 28  blackassign55                736
# 29  blackassign58                127

# %%
tempdf = tempdf.sort_values(by='file', key=lambda x: x.map(natural_sort_key))

# %%
tempdf.head(50)
# Out:
#              file complex word count
# 66   blackassign1                884
# 54   blackassign2               1095
# 3    blackassign3                747
# 8    blackassign4                768
# 49   blackassign5                467
# 40   blackassign6               1237
# 65   blackassign7                918
# 13   blackassign8                548
# 63   blackassign9                672
# 90  blackassign10               2480
# 45  blackassign11               1011
# 9   blackassign12               1123
# 32  blackassign13                420
# 53  blackassign14                 10
# 73  blackassign15                847
# 83  blackassign16                847
# 15  blackassign17                789
# 33  blackassign18                731
# 78  blackassign19               1201
# 0   blackassign20                  7
# 20  blackassign21                781
# 96  blackassign22                297
# 31  blackassign23                988
# 79  blackassign24                384
# 55  blackassign25                729
# 62  blackassign26                653
# 6   blackassign27                955
# 7   blackassign28                771
# 2   blackassign29                  9
# 72  blackassign30               1038
# 99  blackassign31               1259
# 19  blackassign32               1173
# 94  blackassign33               1261
# 59  blackassign34                943
# 27  blackassign35                557
# 38  blackassign36                  5
# 17  blackassign37                521
# 61  blackassign38               1549
# 48  blackassign39               1427
# 92  blackassign40                844
# 98  blackassign41                905
# 25  blackassign42               1150
# 30  blackassign43                  9
# 51  blackassign44                382
# 22  blackassign45               1310
# 35  blackassign46                650
# 64  blackassign47                516
# 10  blackassign48                202
# 46  blackassign49                  5
# 39  blackassign50                970

# %%
df.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#   POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0             41              5        0.782609           0.038429
# 1             54             22        0.421053           0.052741
# 2             35             19        0.296296            0.05104
# 3             32             58       -0.288889           0.086622
# 4             18              7        0.440000           0.036819
#
#    AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS FOG INDEX  \
# 0                  598                    0.584795       NaN
# 1                   80                   29.770992       NaN
# 2                 1058                    0.850662       NaN
# 3                   22                   71.896054       NaN
# 4                    6                  183.505155       NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT  \
# 0                               598                  7       1197
# 1                                80                429       1441
# 2                              1058                  9       1058
# 3                                22                747       1039
# 4                                 6               1246        679
#
#   SYLLABLE PER WORD PERSONAL PRONOUNS  AVG WORD LENGHT
# 0                18                 1                0
# 1              1105                17                2
# 2                17                 0                0
# 3              2338                28                6
# 4              3116                62               13

# %%
score_dataframe.head(80)
# Out:
#              file positive score negative score  polarity score  \
# 0    blackassign1             41              5        0.782609
# 1    blackassign2             54             22        0.421053
# 2    blackassign3             35             19        0.296296
# 3    blackassign4             32             58       -0.288889
# 4    blackassign5             18              7        0.440000
# ..            ...            ...            ...             ...
# 75  blackassign76             46             27        0.260274
# 76  blackassign77             19              9        0.357143
# 77  blackassign78             34             18        0.307692
# 78  blackassign79             31             32       -0.015873
# 79  blackassign80             18             10        0.285714
#
#    total word count total sentence count subjectivity score  \
# 0              1197                    2           0.038429
# 1              1441                   18           0.052741
# 2              1058                    1            0.05104
# 3              1039                   46           0.086622
# 4               679                  104           0.036819
# ..              ...                  ...                ...
# 75             1541                   65           0.047372
# 76              765                   35           0.036601
# 77             1170                   30           0.044444
# 78             1597                   72           0.039449
# 79             3252                   15            0.00861
#
#     average sentence lenght complex word count percentage of complex words  \
# 0                       598                  7                    0.584795
# 1                        80                429                   29.770992
# 2                      1058                  9                    0.850662
# 3                        22                747                   71.896054
# 4                         6               1246                  183.505155
# ..                      ...                ...                         ...
# 75                       23                856                   55.548345
# 76                       21                806                  105.359477
# 77                       39                800                   68.376068
# 78                       22               1201                   75.203507
# 79                      216                384                   11.808118
#
#    syllable count personal pronoun count character count  average word length
# 0              18                      1              50                    0
# 1            1105                     17            3203                    2
# 2              17                      0              49                    0
# 3            2338                     28            6596                    6
# 4            3116                     62            9016                   13
# ..            ...                    ...             ...                  ...
# 75           2073                     67            5898                    3
# 76           2321                     40            6591                    8
# 77           1941                     43            5497                    4
# 78           3212                    100            9255                    5
# 79           1062                     13            3017                    0
#
# [80 rows x 14 columns]

# %%
score_dataframe['complex word count'] = tempdf['complex word count']

# %%
score_dataframe.head()
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13

# %%
score_dataframe['percentage of complex words'] = (score_dataframe['complex word count']/score_dataframe['total word count'])*100

# %%
score_dataframe.head()
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13

# %%
score_dataframe['fog index'] = 0.4*(score_dataframe['average sentence lenght']+score_dataframe['percentage of complex words'])
score_dataframe.head()
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length  \
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13
#
#     fog index
# 0  239.433918
# 1   43.908397
# 2  423.540265
# 3   37.558422
# 4   75.802062

# %%
# Initializing an empty DataFrame to store results
score_df = pd.DataFrame(columns=['File_Name', 'Syllable_Count', 'Personal_Pronoun_Count'])

# Processing each text file
for file_name in file_names:
    # Creating the full file path
    file_path = os.path.join(folder_path, file_name)

    # Reading the content of the text file
    with open(file_path, 'r', encoding='utf-8') as file:
        text_content = file.read()

        # Counting syllables in the text
        syllable_counts = count_syllables_in_text(text_content)

        # Counting personal pronouns in the text
        pronoun_count = count_personal_pronouns(text_content)

        # Saving the results in the DataFrame
        file_data = {'File_Name': file_name, 'Syllable_Count': sum(syllable_counts), 'Personal_Pronoun_Count': pronoun_count}
        score_df = score_df.append(file_data, ignore_index=True)
# Out:
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)
# <ipython-input-251-ed86c73d931f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_df = score_df.append(file_data, ignore_index=True)

# %%
score_df = score_df.sort_values(by='File_Name', key=lambda x: x.map(natural_sort_key))

# %%
score_df.head()
# Out:
#        File_Name Syllable_Count Personal_Pronoun_Count
# 66  blackassign1           2058                     70
# 54  blackassign2           2885                     35
# 3   blackassign3           2338                     28
# 8   blackassign4           2232                     21
# 49  blackassign5           1283                     22

# %%
score_dataframe['syllable count'] = score_df['Syllable_Count']
score_dataframe['personal pronoun count'] = score_df['Personal_Pronoun_Count']
score_dataframe.head()
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length  \
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13
#
#     fog index
# 0  239.433918
# 1   43.908397
# 2  423.540265
# 3   37.558422
# 4   75.802062

# %%
print(score_dataframe.columns)
# Out:
# Index(['file', 'positive score', 'negative score', 'polarity score',
#        'total word count', 'total sentence count', 'subjectivity score',
#        'average sentence lenght', 'complex word count',
#        'percentage of complex words', 'syllable count',
#        'personal pronoun count', 'character count', 'average word length',
#        'fog index'],
#       dtype='object')

# %%
print(score_dataframe.head())
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length  \
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13
#
#     fog index
# 0  239.433918
# 1   43.908397
# 2  423.540265
# 3   37.558422
# 4   75.802062

# %%
df['POSITIVE SCORE'] = score_dataframe['positive score']
df['NEGATIVE SCORE'] = score_dataframe['negative score']
df['POLARITY SCORE'] = score_dataframe['polarity score']
df['AVG SENTENCE LENGTH'] = score_dataframe['average sentence lenght']
df['SUBJECTIVITY SCORE'] = score_dataframe['subjectivity score']
df['FOG INDEX'] = score_dataframe['fog index']
df['SYLLABLE PER WORD'] = score_dataframe['syllable count']
df['AVG NUMER OF WORDS PER SENTENCE'] = score_dataframe['average sentence lenght']
df['PERCENTAGE OF COMPLEX WORDS'] = score_dataframe['percentage of complex words']
df['COMPLEX WORD COUNT'] = score_dataframe['complex word count']
df['WORD COUNT'] = score_dataframe['total word count']
df['PERSONAL PRONOUNS'] = score_dataframe['personal pronoun count']

# %%
df.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#   POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0             41              5        0.782609           0.038429
# 1             54             22        0.421053           0.052741
# 2             35             19        0.296296            0.05104
# 3             32             58       -0.288889           0.086622
# 4             18              7        0.440000           0.036819
#
#    AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS   FOG INDEX  \
# 0                  598                    0.584795  239.433918
# 1                   80                   29.770992   43.908397
# 2                 1058                    0.850662  423.540265
# 3                   22                   71.896054   37.558422
# 4                    6                  183.505155   75.802062
#
#    AVG NUMBER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT  \
# 0                               598                  7       1197
# 1                                80                429       1441
# 2                              1058                  9       1058
# 3                                22                747       1039
# 4                                 6               1246        679
#
#   SYLLABLE PER WORD PERSONAL PRONOUNS  AVG WORD LENGHT  \
# 0                18                 1                0
# 1              1105                17                2
# 2                17                 0                0
# 3              2338                28                6
# 4              3116                62               13
#
#    AVG NUMER OF WORDS PER SENTENCE
# 0                              598
# 1                               80
# 2                             1058
# 3                               22
# 4                                6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_43['POLARITY SCORE'].plot(kind='hist', bins=20, title='POLARITY SCORE')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_44['AVG SENTENCE LENGTH'].plot(kind='hist', bins=20, title='AVG SENTENCE LENGTH')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45['AVG NUMBER OF WORDS PER SENTENCE'].plot(kind='hist', bins=20, title='AVG NUMBER OF WORDS PER SENTENCE')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46['AVG WORD LENGHT'].plot(kind='hist', bins=20, title='AVG WORD LENGHT')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_47.groupby('URL_ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_48.groupby('URL').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_49.groupby('POSITIVE SCORE').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_50.groupby('NEGATIVE SCORE').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_51.plot(kind='scatter', x='POLARITY SCORE', y='AVG SENTENCE LENGTH', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_52.plot(kind='scatter', x='AVG SENTENCE LENGTH', y='AVG NUMBER OF WORDS PER SENTENCE', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_53.plot(kind='scatter', x='AVG NUMBER OF WORDS PER SENTENCE', y='AVG WORD LENGHT', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_54.plot(kind='scatter', x='AVG WORD LENGHT', y='AVG NUMER OF WORDS PER SENTENCE', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_55['POLARITY SCORE'].plot(kind='line', figsize=(8, 4), title='POLARITY SCORE')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_56['AVG SENTENCE LENGTH'].plot(kind='line', figsize=(8, 4), title='AVG SENTENCE LENGTH')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_57['AVG NUMBER OF WORDS PER SENTENCE'].plot(kind='line', figsize=(8, 4), title='AVG NUMBER OF WORDS PER SENTENCE')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_58['AVG WORD LENGHT'].plot(kind='line', figsize=(8, 4), title='AVG WORD LENGHT')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['URL'].value_counts()
#     for x_label, grp in _df_59.groupby('URL_ID')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('URL_ID')
# _ = plt.ylabel('URL')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['POSITIVE SCORE'].value_counts()
#     for x_label, grp in _df_60.groupby('URL')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('URL')
# _ = plt.ylabel('POSITIVE SCORE')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['NEGATIVE SCORE'].value_counts()
#     for x_label, grp in _df_61.groupby('POSITIVE SCORE')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('POSITIVE SCORE')
# _ = plt.ylabel('NEGATIVE SCORE')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['SUBJECTIVITY SCORE'].value_counts()
#     for x_label, grp in _df_62.groupby('NEGATIVE SCORE')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('NEGATIVE SCORE')
# _ = plt.ylabel('SUBJECTIVITY SCORE')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_63['URL_ID'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_63, x='POLARITY SCORE', y='URL_ID', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_64['URL'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_64, x='POLARITY SCORE', y='URL', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_65['POSITIVE SCORE'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_65, x='POLARITY SCORE', y='POSITIVE SCORE', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_66['NEGATIVE SCORE'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_66, x='POLARITY SCORE', y='NEGATIVE SCORE', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df = df.loc[:, ~df.columns.duplicated()]

# %%
df.rename(columns = {'AVG NUMER OF WORDS PER SENTENCE':'AVG NUMBER OF WORDS PER SENTENCE'},inplace = True)
# Out:
# <ipython-input-158-7b59b12f3dff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'AVG NUMER OF WORDS PER SENTENCE':'AVG NUMBER OF WORDS PER SENTENCE'},inplace = True)

# %%
df.head
# Out:
# <bound method NDFrame.head of              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# 5   blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# 6   blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# 7   blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# 8   blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# 9   blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
# 10  blackassign0011  https://insights.blackcoffer.com/rise-of-inter...
# 11  blackassign0012  https://insights.blackcoffer.com/rise-of-telem...
# 12  blackassign0013  https://insights.blackcoffer.com/rise-of-e-hea...
# 13  blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# 14  blackassign0015  https://insights.blackcoffer.com/rise-of-telem...
# 15  blackassign0016  https://insights.blackcoffer.com/rise-of-telem...
# 16  blackassign0017  https://insights.blackcoffer.com/rise-of-chatb...
# 17  blackassign0018  https://insights.blackcoffer.com/rise-of-e-hea...
# 18  blackassign0019  https://insights.blackcoffer.com/how-does-mark...
# 19  blackassign0020  https://insights.blackcoffer.com/how-advertise...
#
#    POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0              41              5        0.782609           0.038429
# 1              54             22        0.421053           0.052741
# 2              35             19        0.296296            0.05104
# 3              32             58       -0.288889           0.086622
# 4              18              7        0.440000           0.036819
# 5              71             21        0.543478           0.051339
# 6              29             51       -0.275000           0.062794
# 7              28              7        0.600000           0.046235
# 8              33             36       -0.043478           0.073718
# 9             129            133       -0.015267           0.073164
# 10             58             13        0.633803           0.050141
# 11             69             19        0.568182           0.053856
# 12             40             11        0.568627           0.082391
# 13              0              0        0.000000                0.0
# 14             39             24        0.238095           0.051724
# 15             39             24        0.238095           0.051724
# 16             47             10        0.649123           0.049782
# 17             37              6        0.720930           0.040913
# 18             55              5        0.833333           0.035482
# 19              0              0        0.000000                0.0
#
#     AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS FOG INDEX  \
# 0                   598                    0.584795       NaN
# 1                    80                   29.770992       NaN
# 2                  1058                    0.850662       NaN
# 3                    22                   71.896054       NaN
# 4                     6                  183.505155       NaN
# 5                    77                   15.178571       NaN
# 6                    28                   74.960754       NaN
# 7                    27                  101.849406       NaN
# 8                    24                   82.051282       NaN
# 9                    63                   31.359955       NaN
# 10                  708                   14.265537       NaN
# 11                 1634                    0.367197       NaN
# 12                   19                  108.723748       NaN
# 13                    0                 3653.333333       NaN
# 14                   17                  102.791461       NaN
# 15                   27                   64.778325       NaN
# 16                  190                   11.266376       NaN
# 17                   35                   49.571836       NaN
# 18                   24                   60.910704       NaN
# 19                    0                13033.333333       NaN
#
#     AVG NUMBER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT  \
# 0                                598                  7       1197
# 1                                 80                429       1441
# 2                               1058                  9       1058
# 3                                 22                747       1039
# 4                                  6               1246        679
# 5                                 77                272       1792
# 6                                 28                955       1274
# 7                                 27                771        757
# 8                                 24                768        936
# 9                                 63               1123       3581
# 10                               708                202       1416
# 11                              1634                  6       1634
# 12                                19                673        619
# 13                                 0                548         15
# 14                                17               1252       1218
# 15                                27                789       1218
# 16                               190                129       1145
# 17                                35                521       1051
# 18                                24               1030       1691
# 19                                 0               1173          9
#
#    SYLLABLE PER WORD PERSONAL PRONOUNS AVG WORD LENGHT
# 0                 18                 1             NaN
# 1               1105                17             NaN
# 2                 17                 0             NaN
# 3               2338                28             NaN
# 4               3116                62             NaN
# 5                716                16             NaN
# 6               2230                59             NaN
# 7               2068                34             NaN
# 8               2232                21             NaN
# 9               3402                47             NaN
# 10               628                11             NaN
# 11                 9                 0             NaN
# 12              1724                29             NaN
# 13              1723                11             NaN
# 14              3105                84             NaN
# 15              2240                35             NaN
# 16               336                 9             NaN
# 17              1228                44             NaN
# 18              2442                57             NaN
# 19              2845                62             NaN  >

# %%
def character_count(text):
  filtered_text = re.sub(r'[^a-zA-Z0-9]', '', text)
  character_count = len(filtered_text)
  return character_count
temp2df = pd.DataFrame(columns = ['file','character count'])
for file in os.listdir(folder):
  file_path = os.path.join(folder, file)
  file_part = os.path.splitext(file)[0]
  with open(file_path,'r') as raw:
    text = raw.read()
  characters = character_count(text)
  temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)

temp2df = temp2df.sort_values(by='file', key=lambda x: x.map(natural_sort_key))
# Out:
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)
# <ipython-input-160-d8ec5672454c>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp2df = temp2df.append({'file': file_part, 'character count': characters}, ignore_index = True)

# %%
temp2df = temp2df.sort_values(by='file', key=lambda x: x.map(natural_sort_key))
temp2df.head()
# Out:
#             file character count
# 66  blackassign1            5687
# 54  blackassign2            8092
# 3   blackassign3            6596
# 8   blackassign4            6343
# 49  blackassign5            3837
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_67.groupby('file').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_68.groupby('character count').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['character count'].value_counts()
#     for x_label, grp in _df_69.groupby('file')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('file')
# _ = plt.ylabel('character count')

# %%
score_dataframe['character count'] = temp2df['character count']

# %%
score_dataframe.head()
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length  \
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13
#
#     fog index
# 0  239.433918
# 1   43.908397
# 2  423.540265
# 3   37.558422
# 4   75.802062
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_70['polarity score'].plot(kind='hist', bins=20, title='polarity score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_71['average sentence lenght'].plot(kind='hist', bins=20, title='average sentence lenght')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_72['average word length'].plot(kind='hist', bins=20, title='average word length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_73.groupby('file').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_74.groupby('positive score').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_75.groupby('negative score').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_76.groupby('total word count').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_77.plot(kind='scatter', x='polarity score', y='average sentence lenght', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_78.plot(kind='scatter', x='average sentence lenght', y='average word length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_79['polarity score'].plot(kind='line', figsize=(8, 4), title='polarity score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_80['average sentence lenght'].plot(kind='line', figsize=(8, 4), title='average sentence lenght')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_81['average word length'].plot(kind='line', figsize=(8, 4), title='average word length')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['positive score'].value_counts()
#     for x_label, grp in _df_82.groupby('file')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('file')
# _ = plt.ylabel('positive score')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['negative score'].value_counts()
#     for x_label, grp in _df_83.groupby('positive score')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('positive score')
# _ = plt.ylabel('negative score')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['total word count'].value_counts()
#     for x_label, grp in _df_84.groupby('negative score')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('negative score')
# _ = plt.ylabel('total word count')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['total sentence count'].value_counts()
#     for x_label, grp in _df_85.groupby('total word count')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('total word count')
# _ = plt.ylabel('total sentence count')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_86['file'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_86, x='polarity score', y='file', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_87['positive score'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_87, x='polarity score', y='positive score', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_88['negative score'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_88, x='polarity score', y='negative score', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_89['total word count'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_89, x='polarity score', y='total word count', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
print(score_dataframe.head())
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length  \
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13
#
#     fog index
# 0  239.433918
# 1   43.908397
# 2  423.540265
# 3   37.558422
# 4   75.802062

# %%
score_dataframe['character count'] = temp2df['character count']

# %%
score_dataframe['average word length'] = (score_dataframe['character count']/score_dataframe['total word count']).apply(math.floor)

# %%
score_dataframe.head()
# Out:
#            file positive score negative score  polarity score  \
# 0  blackassign1             41              5        0.782609
# 1  blackassign2             54             22        0.421053
# 2  blackassign3             35             19        0.296296
# 3  blackassign4             32             58       -0.288889
# 4  blackassign5             18              7        0.440000
#
#   total word count total sentence count subjectivity score  \
# 0             1197                    2           0.038429
# 1             1441                   18           0.052741
# 2             1058                    1            0.05104
# 3             1039                   46           0.086622
# 4              679                  104           0.036819
#
#    average sentence lenght complex word count percentage of complex words  \
# 0                      598                  7                    0.584795
# 1                       80                429                   29.770992
# 2                     1058                  9                    0.850662
# 3                       22                747                   71.896054
# 4                        6               1246                  183.505155
#
#   syllable count personal pronoun count character count  average word length  \
# 0             18                      1              50                    0
# 1           1105                     17            3203                    2
# 2             17                      0              49                    0
# 3           2338                     28            6596                    6
# 4           3116                     62            9016                   13
#
#     fog index
# 0  239.433918
# 1   43.908397
# 2  423.540265
# 3   37.558422
# 4   75.802062
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_90['polarity score'].plot(kind='hist', bins=20, title='polarity score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_91['average sentence lenght'].plot(kind='hist', bins=20, title='average sentence lenght')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_92['average word length'].plot(kind='hist', bins=20, title='average word length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_93.groupby('file').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_94.groupby('positive score').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_95.groupby('negative score').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_96.groupby('total word count').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_97.plot(kind='scatter', x='polarity score', y='average sentence lenght', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_98.plot(kind='scatter', x='average sentence lenght', y='average word length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_99['polarity score'].plot(kind='line', figsize=(8, 4), title='polarity score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_100['average sentence lenght'].plot(kind='line', figsize=(8, 4), title='average sentence lenght')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_101['average word length'].plot(kind='line', figsize=(8, 4), title='average word length')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['positive score'].value_counts()
#     for x_label, grp in _df_102.groupby('file')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('file')
# _ = plt.ylabel('positive score')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['negative score'].value_counts()
#     for x_label, grp in _df_103.groupby('positive score')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('positive score')
# _ = plt.ylabel('negative score')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['total word count'].value_counts()
#     for x_label, grp in _df_104.groupby('negative score')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('negative score')
# _ = plt.ylabel('total word count')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['total sentence count'].value_counts()
#     for x_label, grp in _df_105.groupby('total word count')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('total word count')
# _ = plt.ylabel('total sentence count')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_106['file'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_106, x='polarity score', y='file', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_107['positive score'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_107, x='polarity score', y='positive score', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_108['negative score'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_108, x='polarity score', y='negative score', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_109['total word count'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_109, x='polarity score', y='total word count', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df['AVG WORD LENGHT'] = score_dataframe['average word length']

# %%
df.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#   POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0             41              5        0.782609           0.038429
# 1             54             22        0.421053           0.052741
# 2             35             19        0.296296            0.05104
# 3             32             58       -0.288889           0.086622
# 4             18              7        0.440000           0.036819
#
#    AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS   FOG INDEX  \
# 0                  598                    0.584795  239.433918
# 1                   80                   29.770992   43.908397
# 2                 1058                    0.850662  423.540265
# 3                   22                   71.896054   37.558422
# 4                    6                  183.505155   75.802062
#
#    AVG NUMBER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT  \
# 0                               598                  7       1197
# 1                                80                429       1441
# 2                              1058                  9       1058
# 3                                22                747       1039
# 4                                 6               1246        679
#
#   SYLLABLE PER WORD PERSONAL PRONOUNS  AVG WORD LENGHT  \
# 0                18                 1                0
# 1              1105                17                2
# 2                17                 0                0
# 3              2338                28                6
# 4              3116                62               13
#
#    AVG NUMER OF WORDS PER SENTENCE
# 0                              598
# 1                               80
# 2                             1058
# 3                               22
# 4                                6

# %%
df.to_csv('/content/Output_reordered.csv', index=False)

# %%
df = df.rename({'AVG WORD LENGHT':'AVG WORD LENGTH'})

# %%
df.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#   POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE SUBJECTIVITY SCORE  \
# 0             41              5        0.782609           0.038429
# 1             54             22        0.421053           0.052741
# 2             35             19        0.296296            0.05104
# 3             32             58       -0.288889           0.086622
# 4             18              7        0.440000           0.036819
#
#    AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS   FOG INDEX  \
# 0                  598                    0.584795  239.433918
# 1                   80                   29.770992   43.908397
# 2                 1058                    0.850662  423.540265
# 3                   22                   71.896054   37.558422
# 4                    6                  183.505155   75.802062
#
#    AVG NUMBER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT  \
# 0                               598                  7       1197
# 1                                80                429       1441
# 2                              1058                  9       1058
# 3                                22                747       1039
# 4                                 6               1246        679
#
#   SYLLABLE PER WORD PERSONAL PRONOUNS  AVG WORD LENGHT  \
# 0                18                 1                0
# 1              1105                17                2
# 2                17                 0                0
# 3              2338                28                6
# 4              3116                62               13
#
#    AVG NUMER OF WORDS PER SENTENCE
# 0                              598
# 1                               80
# 2                             1058
# 3                               22
# 4                                6

# %%
df.to_csv('output_file.csv', index=False)
